# %% [markdown]
# ## NLP Hands-On 31-07-2020

# %%
import nltk

# %% [markdown]
# #### Task 1: Basic Text Processing

# %%
text1 = "Here's to the crazy ones. The misfits. The rebels. The troublemakers. The round pegs in the square holes. The ones who see things differently. They're not fond of rules. And they have no respect for the status quo. You can quote them, disagree with them, glorify or vilify them. About the only thing you can't do is ignore them. Because they change things. They push the human race forward. And while some may see them as the crazy ones, we see genius. Because the people who are crazy enough to think they can change the world, are the ones who do."

# %%
for text in text1:
    sentences = nltk.sent_tokenize(text1)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('Here', 'RB'), ("'s", 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('crazy', 'JJ'), ('ones', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('misfits', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('rebels', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('troublemakers', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('round', 'NN'), ('pegs', 'NN'), ('in', 'IN'), ('the', 'DT'), ('square', 'NN'), ('holes', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('ones', 'NNS'), ('who', 'WP'), ('see', 'VBP'), ('things', 'NNS'), ('differently', 'RB'), ('.', '.')]
# [('They', 'PRP'), ("'re", 'VBP'), ('not', 'RB'), ('fond', 'JJ'), ('of', 'IN'), ('rules', 'NNS'), ('.', '.')]
# [('And', 'CC'), ('they', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('respect', 'NN'), ('for', 'IN'), ('the', 'DT'), ('status', 'NN'), ('quo', 'NN'), ('.', '.')]
# ...

# %% [markdown]
# #### Task 2 : Tweet Tokenizer

# %%
from nltk.tokenize import TweetTokenizer
text = "Build a waaaallll against Mexico ASAP !!!!"
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['Build', 'a', 'waaaallll', 'against', 'Mexico', 'ASAP', '!', '!', '!']

# %% [markdown]
# #### Task 3: Scraping the Data from Web

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
len(raw)
raw[:75]
from nltk.tokenize import word_tokenize
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %% [markdown]
# #### Task 4: Handling Tweets Data

# %%
import nltk
f = open('tweets1.txt' , 'r')
text = f.read()
text1 = text.split()
text2 = nltk.Text(text1)
text2.concordance("great")
# Out:
# Displaying 16 of 16 matches:
#  cracked on valentine's. There is no great genius without a drop of madness, am
# reet. sketchy sketchy. The Departed: Great movie! Can see why it won so many Os
# reat, but just about anything tastes great with a kilogram of parmesean cheese
# ck .. not bad so far! Studying had a great time out with the guys.. talked abou
# torage since they travel -- but it's great otherwise changed my mind and ordere
# .com. I can SMS or email pics to it! great read. interesting thesis: interactio
# peared a few hours ago. Johnny Lee's great wiimote projects: url ... headtracki
# . investigating broadband speeds url Great news coming soon :) I hate having to
# t the blog news for Tuesday 01.29.08 great day!!! See you in Rome next Summer?
#  apple store Eating at zippys What a great days at Lift Conference in Geneva...
# ) Watching jesse on all my children. Great news for HCA employees! Read about c
# ...
